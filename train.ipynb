# %%
import os
from ultralytics import YOLO
from PIL import Image
import cv2

# %%
# Load the model.
model = YOLO('yolov8n.pt')

# Training.
results = model.train(
   data='/home/kagan/Desktop/Documents/Projects/Ship-Type-Determination-YOLOV5/V-1.0/database/data.yaml',
   imgsz=245,
   epochs=300,
   batch=8,
   name='yolov8n_custom')
# Out:
# New https://pypi.org/project/ultralytics/8.0.52 available 😃 Update with 'pip install -U ultralytics'
# /home/kagan/anaconda3/lib/python3.9/site-packages/torch/cuda/__init__.py:88: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 9010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# Ultralytics YOLOv8.0.50 🚀 Python-3.9.13 torch-1.13.1+cu117 CPU
# ...

# %%
results = model.val()
# Out:
# Ultralytics YOLOv8.0.50 🚀 Python-3.9.13 torch-1.13.1+cu117 CPU
# Model summary (fused): 168 layers, 3007988 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/kagan/Desktop/Documents/Projects/Ship-Type-Determination-YOLOV5/V-1.0/database/valid/labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.89it/s]
#                    all         30         30      0.949      0.916       0.98      0.728
#           Bulk-Carrier         30          5      0.947          1      0.995      0.818
#         Container Ship         30          4          1      0.937      0.995      0.688
#            Cruise Ship         30          5          1      0.926      0.995      0.877
#                    LNG         30          4      0.771       0.75      0.888      0.576
# ...
